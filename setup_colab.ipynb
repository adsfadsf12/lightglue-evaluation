# %% [markdown]
# # LightGlue 평가 - Colab 설정
#
# ## Step 1: GitHub 클론
# !git clone https://github.com/YOUR_USERNAME/lightglue-evaluation.git
# %cd lightglue-evaluation
#
# ## Step 2: 데이터 확인
# !ls -lh data/v_poster/
# !ls -lh data/illumination_change/
#
# ## Step 3: 패키지 설치
# !pip install -q torch torchvision opencv-python matplotlib pandas tqdm pyyaml
# !pip install -q git+https://github.com/cvg/LightGlue.git
#
# ## Step 4: SuperGlue 다운로드
# !git clone https://github.com/magicleap/SuperGluePretrainedNetwork.git models/SuperGlue
# import sys
# sys.path.append('./models/SuperGlue')
#
# ## Step 5: Viewpoint 평가
# !python scripts/eval_homography.py --dataset v_poster
#
# ## Step 6: Illumination 평가
# !python scripts/eval_homography.py --dataset illumination

# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# LightGlue 이미지 매칭 평가\n",
    "\n",
    "**GitHub에서 바로 클론하여 실행 가능!**\n",
    "\n",
    "- ✅ v_poster (Viewpoint Change)\n",
    "- ✅ illumination_change (Illumination Change)  \n",
    "- ✅ KITTI Sequence 00 (Pose Estimation) - 13장만 포함"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# ===== Step 1: GitHub 클론 =====\n",
    "# ⚠️ YOUR_USERNAME을 본인 GitHub 아이디로 변경!\n",
    "\n",
    "!git clone https://github.com/YOUR_USERNAME/lightglue-evaluation.git\n",
    "%cd lightglue-evaluation\n",
    "\n",
    "print('✓ Repository cloned')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# ===== Step 2: 데이터 확인 =====\n",
    "\n",
    "!echo \"=== v_poster ===\"\n",
    "!ls -lh data/v_poster/ | head -n 5\n",
    "\n",
    "!echo \"\\n=== illumination_change ===\"\n",
    "!ls -lh data/illumination_change/ | head -n 5\n",
    "\n",
    "!echo \"\\n=== kitti ===\"\n",
    "!ls -lh data/kitti/images/ | head -n 5\n",
    "!ls -lh data/kitti/poses.txt"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# ===== Step 3: 패키지 설치 =====\n",
    "\n",
    "!pip install -q torch torchvision opencv-python matplotlib pandas tqdm pyyaml\n",
    "!pip install -q git+https://github.com/cvg/LightGlue.git\n",
    "\n",
    "print('✓ Packages installed')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# ===== Step 4: SuperGlue 다운로드 =====\n",
    "\n",
    "!git clone https://github.com/magicleap/SuperGluePretrainedNetwork.git models/SuperGlue\n",
    "\n",
    "import sys\n",
    "sys.path.append('./models/SuperGlue')\n",
    "\n",
    "print('✓ SuperGlue ready')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# ===== Step 5: Viewpoint Change 평가 =====\n",
    "\n",
    "!python scripts/eval_homography.py --dataset v_poster"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# ===== Step 6: Illumination Change 평가 =====\n",
    "\n",
    "!python scripts/eval_homography.py --dataset illumination"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# ===== Step 7: KITTI Pose 추정 평가 =====\n",
    "\n",
    "!python scripts/eval_kitti.py"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## ✅ 완료!\n",
    "\n",
    "모든 평가가 완료되었습니다. 결과는 위 셀에서 확인하세요."
   ]
  }
 ],
 "metadata": {
  "accelerator": "GPU",
  "colab": {
   "gpuType": "T4",
   "provenance": []
  },
  "kernelspec": {
   "display_name": "Python 3",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 0
}
